# %%
# !pip install -q datasets pandas pymongo sentence_transformers

# %%
# !pip install -q accelerate

# %%
# !pip install pymongo[srv]
# Out:
# Requirement already satisfied: pymongo[srv] in /usr/local/lib/python3.12/dist-packages (4.15.4)
# WARNING: pymongo 4.15.4 does not provide the extra 'srv'
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /usr/local/lib/python3.12/dist-packages (from pymongo[srv]) (2.8.0)

# %%
import pymongo
import pandas as pd
from google.colab import userdata

# %%
# Connect to MongoDB
# VNLaws
# vnlaw1234
# mongodb+srv://VNLaws:<db_password>@rag-cluster.issqlbf.mongodb.net/?appName=rag-cluster
from pymongo import MongoClient

client = MongoClient(
    "mongodb+srv://VNLaws:<L!nkboong91>@rag-cluster.issqlbf.mongodb.net/?appName=rag-cluster"
)

# pymongo.MongoClient(userdata.get('mongo_url')) #Update MongoDB connection string
db = client["DBName"]
collection = db["article_details_clean"]
df.drop('_id', axis=1, inplace = True)
df.drop('url', axis =1, inplace = True)

# %%
#Retrieve data from MongoDB
data = list(collection.find()) #search all collection (table) in MongoDB to data frame
#Convert data to Data Frame using Pandas
df = pd.DataFrame(data)
#Preprocessing Data here
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# /tmp/ipython-input-3515486966.py in <cell line: 0>()
#       1 #Retrieve data from MongoDB
# ----> 2 data = list(collection.find())
#       3 #Convert data to Data Frame using Pandas
#       4 df = pd.DataFrame(data)
#       5 #Preprocessing Data here
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/cursor.py in __next__(self)
#    1287
#    1288     def __next__(self) -> _DocumentType:
# -> 1289         return self.next()
#    1290
#    1291     def __iter__(self) -> Cursor[_DocumentType]:
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/cursor.py in next(self)
#    1263         if self._empty:
#    1264             raise StopIteration
# -> 1265         if len(self._data) or self._refresh():
#    1266             return self._data.popleft()
#    1267         else:
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/cursor.py in _refresh(self)
#    1211                 self._exhaust,
#    1212             )
# -> 1213             self._send_message(q)
#    1214         elif self._id:  # Get More
#    1215             if self._limit:
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/cursor.py in _send_message(self, operation)
#    1106
#    1107         try:
# -> 1108             response = client._run_operation(
#    1109                 operation, self._unpack_response, address=self._address
#    1110             )
#
# /usr/local/lib/python3.12/dist-packages/pymongo/_csot.py in csot_wrapper(self, *args, **kwargs)
#     123                     with _TimeoutContext(timeout):
#     124                         return func(self, *args, **kwargs)
# --> 125             return func(self, *args, **kwargs)
#     126
#     127     return cast(F, csot_wrapper)
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in _run_operation(self, operation, unpack_res, address)
#    1936             )
#    1937
# -> 1938         return self._retryable_read(
#    1939             _cmd,
#    1940             operation.read_preference,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in _retryable_read(self, func, read_pref, session, operation, address, retryable, operation_id)
#    2045             retryable and self.options.retry_reads and not (session and session.in_transaction)
#    2046         )
# -> 2047         return self._retry_internal(
#    2048             func,
#    2049             session,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/_csot.py in csot_wrapper(self, *args, **kwargs)
#     123                     with _TimeoutContext(timeout):
#     124                         return func(self, *args, **kwargs)
# --> 125             return func(self, *args, **kwargs)
#     126
#     127     return cast(F, csot_wrapper)
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in _retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    2012             retryable=retryable,
#    2013             operation_id=operation_id,
# -> 2014         ).run()
#    2015
#    2016     def _retryable_read(
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in run(self)
#    2763             self._check_last_error(check_csot=True)
#    2764             try:
# -> 2765                 return self._read() if self._is_read else self._write()
#    2766             except ServerSelectionTimeoutError:
#    2767                 # The application may think the write was never attempted
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in _read(self)
#    2910         self._server = self._get_server()
#    2911         assert self._read_pref is not None, "Read Preference required on read calls"
# -> 2912         with self._client._conn_from_server(self._read_pref, self._server, self._session) as (
#    2913             conn,
#    2914             read_pref,
#
# /usr/lib/python3.12/contextlib.py in __enter__(self)
#     135         del self.args, self.kwds, self.func
#     136         try:
# --> 137             return next(self.gen)
#     138         except StopIteration:
#     139             raise RuntimeError("generator didn't yield") from None
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in _conn_from_server(self, read_preference, server, session)
#    1865         # to call _get_topology() again.
#    1866         single = self._topology.description.topology_type == TOPOLOGY_TYPE.Single
# -> 1867         with self._checkout(server, session) as conn:
#    1868             if single:
#    1869                 if conn.is_repl and not (session and session.in_transaction):
#
# /usr/lib/python3.12/contextlib.py in __enter__(self)
#     135         del self.args, self.kwds, self.func
#     136         try:
# --> 137             return next(self.gen)
#     138         except StopIteration:
#     139             raise RuntimeError("generator didn't yield") from None
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in _checkout(self, server, session)
#    1775                 yield session._pinned_connection
#    1776                 return
# -> 1777             with server.checkout(handler=err_handler) as conn:
#    1778                 # Pin this session to the selected server or connection.
#    1779                 if (
#
# /usr/lib/python3.12/contextlib.py in __enter__(self)
#     135         del self.args, self.kwds, self.func
#     136         try:
# --> 137             return next(self.gen)
#     138         except StopIteration:
#     139             raise RuntimeError("generator didn't yield") from None
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/pool.py in checkout(self, handler)
#    1116             )
#    1117
# -> 1118         conn = self._get_conn(checkout_started_time, handler=handler)
#    1119
#    1120         duration = time.monotonic() - checkout_started_time
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/pool.py in _get_conn(self, checkout_started_time, handler)
#    1278                 else:  # We need to create a new connection
#    1279                     try:
# -> 1280                         conn = self.connect(handler=handler)
#    1281                     finally:
#    1282                         with self._max_connecting_cond:
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/pool.py in connect(self, handler)
#    1070                 handler.contribute_socket(conn, completed_handshake=False)
#    1071
# -> 1072             conn.authenticate()
#    1073         # Catch KeyboardInterrupt, CancelledError, etc. and cleanup.
#    1074         except BaseException:
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/pool.py in authenticate(self, reauthenticate)
#     523                 from pymongo.synchronous import auth
#     524
# --> 525                 auth.authenticate(creds, self, reauthenticate=reauthenticate)
#     526             self.ready = True
#     527             duration = time.monotonic() - self.creation_time
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/auth.py in authenticate(credentials, conn, reauthenticate)
#     448         _authenticate_oidc(credentials, conn, reauthenticate)
#     449     else:
# --> 450         auth_func(credentials, conn)
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/auth.py in _authenticate_default(credentials, conn)
#     353             return _authenticate_scram(credentials, conn, "SCRAM-SHA-256")
#     354         else:
# --> 355             return _authenticate_scram(credentials, conn, "SCRAM-SHA-1")
#     356     else:
#     357         return _authenticate_scram(credentials, conn, "SCRAM-SHA-1")
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/auth.py in _authenticate_scram(credentials, conn, mechanism)
#     133         "payload": Binary(client_final),
#     134     }
# --> 135     res = conn.command(source, cmd)
#     136
#     137     parsed = _parse_scram_response(res["payload"])
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/helpers.py in inner(*args, **kwargs)
#      45
#      46         try:
# ---> 47             return func(*args, **kwargs)
#      48         except OperationFailure as exc:
#      49             if no_reauth:
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/pool.py in command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     411             self._raise_if_not_writable(unacknowledged)
#     412         try:
# --> 413             return command(
#     414                 self,
#     415                 dbname,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/network.py in command(conn, dbname, spec, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed, write_concern)
#     210                 client._process_response(response_doc, session)
#     211             if check:
# --> 212                 helpers_shared._check_command_response(
#     213                     response_doc,
#     214                     conn.max_wire_version,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/helpers_shared.py in _check_command_response(response, max_wire_version, allowable_errors, parse_write_concern_error, pool_opts)
#     282         raise CursorNotFound(errmsg, code, response, max_wire_version)
#     283
# --> 284     raise OperationFailure(errmsg, code, response, max_wire_version)
#     285
#     286
#
# OperationFailure: bad auth : authentication failed, full error: {'ok': 0, 'errmsg': 'bad auth : authentication failed', 'code': 8000, 'codeName': 'AtlasError'}

# %%
df.head()

# %%
# !pip install sentence_transformers
# Out:
# Collecting sentence_transformers
#   Downloading sentence_transformers-5.1.2-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.12/dist-packages (from sentence_transformers) (4.57.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from sentence_transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from sentence_transformers) (2.8.0+cpu)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from sentence_transformers) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from sentence_transformers) (1.16.3)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from sentence_transformers) (0.36.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from sentence_transformers) (12.0.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in /usr/local/lib/python3.12/dist-packages (from sentence_transformers) (4.15.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence_transformers) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence_transformers) (2025.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence_transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence_transformers) (6.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence_transformers) (2.32.4)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence_transformers) (1.2.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence_transformers) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence_transformers) (1.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence_transformers) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence_transformers) (3.1.6)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (2.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (0.6.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->sentence_transformers) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->sentence_transformers) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.11.0->sentence_transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.11.0->sentence_transformers) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.20.0->sentence_transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.20.0->sentence_transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.20.0->sentence_transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.20.0->sentence_transformers) (2025.10.5)
# Downloading sentence_transformers-5.1.2-py3-none-any.whl (488 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 488.0/488.0 kB 12.2 MB/s eta 0:00:00
# Installing collected packages: sentence_transformers
# Successfully installed sentence_transformers-5.1.2

# %%
from sentence_transformers import SentenceTransformer
embedding_model = SentenceTransformer("keepitreal/vietnamese-sbert")
def get_embedding(text: str) -> list[float]:
  if not text.strip():
    print("Attempted to get embedding for empty text.")
    return []
  embedding = embedding_model.encode(text)
  return embedding.tolist()
# Out:
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/752 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/540M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/313 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/540M [00:00<?, ?B/s]
# bpe.codes: 0.00B [00:00, ?B/s]
# added_tokens.json:   0%|          | 0.00/17.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/150 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
df["embedding"] = df["title"].apply(get_embedding) #embedding "title" column
df.head
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1603633227.py in <cell line: 0>()
# ----> 1 df["embedding"] = df["title"].apply(get_embedding) #embedding "title" column
#       2 df.head
#
# NameError: name 'df' is not defined

# %%
collection = db["embedding_for_vector_"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2418724427.py in <cell line: 0>()
# ----> 1 collection = db["embedding_for_vector_"]
#
# NameError: name 'db' is not defined

# %%
collection.delete_many({})

# %%
documents = df.to_dict("records")
collection.insert_many(documents)
print("Data ingestion into MongoDB completed")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1613506166.py in <cell line: 0>()
# ----> 1 documents = df.to_dict("records")
#       2 collection.insert_many(documents)
#       3 print("Data ingestion into MongoDB completed")
#
# NameError: name 'df' is not defined
